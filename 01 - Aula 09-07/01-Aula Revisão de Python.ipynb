# %% [markdown]
# <h3>Revisão Lógica: Condicionais</h3>
#
# 1 - Faça um Programa que peça dois números
# ao usuário e imprima o maior deles.
#
# 2 - Faça um Programa que peça ao usuário um
# valor e mostre na tela se o valor é positivo ou
# negativo.
#
# 3 - Faça um Programa que verifique se uma
# letra digitada é "F" ou "M". Conforme a letra
# escrever: F -Feminino, M - Masculino, Sexo Inválido
#
# 4 - Faça um Programa que verifique se a letra
# digitada pelo usuário é vogal ou consoante.
#
# 5 - Faça um programa para a leitura de quatro
# notas de um aluno. O programa deve calcular a
# média alcançada apresentar:
# a. A mensagem "Aprovado", se a média alcançada for
# maior ou igual a sete;
# b. A mensagem "Reprovado", se a média for menor do
# que sete;
# c. A mensagem "Aprovado com Distinção", se a média for
# igual a dez.
#
# 6 - Faça um Programa que receba 2 números e
# em seguida pergunte ao usuário qual operação
# ele deseja realizar. O resultado da operação deve
# aparecer com uma frase que diga se o número é:
# a. par ou ímpar;
# b. positivo ou negativo;
# c. inteiro ou decimal.

# %%
# 1 - Faça um Programa que peça dois números ao usuário e imprima o maior deles.

lista = []
for c in range(2):
    lista.append(int(input(f'Digite o número { c + 1} °: ')))

print(lista)
lista.reverse()
print(f'O maior valor digitado foi : {lista[0]}')

# %%
# 2 - Faça um Programa que peça ao usuário um valor e mostre na tela se o valor é positivo ou negativo.

numero = int(input(f'Digite o número inteiro: '))
verficador = type(numero)
print(verficador)


if numero > 0:
    print(f'O {numero} é positivo')
elif numero == 0:
    print(f'O {numero} é neutro')
elif numero < 0:
    print(f'O {numero} é negativo')

# %%
# 3 - Faça um Programa que verifique se uma letra digitada é "F" ou "M". Conforme a letra escrever: F -Feminino, M - Masculino, Sexo Inválido

sexo = input('Digite F para Feminino ou M para Masculino :')
sexo = sexo[0]
sexo = sexo.upper()

if sexo == 'M':
    print(f'O {sexo} é Masculino ')
elif sexo == 'F':
    print(f'O {sexo} é Feminino ')
else:
    print(f'O {sexo} é Invalido !!!')

# %%
# 4 - Faça um Programa que verifique se a letra digitada pelo usuário é vogal ou consoante.

vogais = 'AEIOUaeiou'

letra = input('Digite uma letra: ')
letra = letra[0]

if letra in vogais:
    print(f'A letra: {letra} é uma Vogal👍👍')
else:
    print(f'A letra: {letra} não é uma Vogal 🤷‍♀️🤦‍♂️')

# %%
# 5 - Faça um programa para a leitura de quatro notas de um aluno. O programa deve calcular a média alcançada apresentar:
# a. A mensagem "Aprovado", se a média alcançada for maior ou igual a 7;
# b. A mensagem "Reprovado", se a média for menor do que 7;
# c. A mensagem "Aprovado com Distinção", se a média for igual a 10.


notas = []
for c in range(4):
    notas.append(float(input(f'Digite a nota { c + 1} °: ')))

media = round((sum(notas)/len(notas)),2)

if media == 10:
    print('Nota 10✨✨:Aprovado com Distinção💖😎')
elif media >= 7:
    print(f' Sua média foi: {media} , que é maior ou igual a 7 : Aprovado 👌👌')
else:
    print(f' Sua média foi: {media} , que é menor que 7 : Reprovado 😢😢')

# %%
# 6 - Faça um Programa que receba 2 números e em seguida pergunte ao usuário qual operação ele deseja realizar. 
# O resultado da operação deve aparecer com uma frase que diga se o número é:
# a. par ou ímpar;
# b. positivo ou negativo;
# c. inteiro ou decimal.

def soma( n1 , n2 ):
    return f' A soma de {n1} + {n2} = { n1 + n2 }'


def sub( n1 , n2 ):
    return f'A subtração de {n1} - {n2} = { n1 - n2 }'


def mul( n1 , n2 ):
    return f'A multiplicação de {n1} * {n2} = { n1 * n2 }'


def div( n1 , n2 ):
    return f'O Resultado da divisão de {n1} / {n2} = { n1 / n2 }'

def verficador(n3):

        if n3%2 == 0:
            n_par = 'Par'
        else:
            n_par = 'Ímpar'
        if n3>0:
            n_positivo = 'Positivo'
        else:
            n_positivo = 'Negativo'
        if n3%1 == 0:
            n_inteiro = 'Inteiro'
        else:
            n_inteiro = 'Decimal'
    
        return f"""

                O número {n3}:

                {n_par}
                {n_positivo}
                {n_inteiro} 
  
                            """

    


while True:
        i=int(input('''\33[32m         
            Olá caro amigo tudo bem 😁😁😁😁
            
            Isso aqui é uma calculaddora para dois
            número a sua escolha senhor(a)
            Selecione a opção desejada:
            
            1- Soma de dois números
            2- Subtração de dois  números
            3- Multiplicação de dois números
            4- Divisão de dois números
            
            5-Para finalizar o Programa
                                            
            Selecione a opção: \33''' ))
        
        if i==1:
            print(' O selecionado foi',i,'soma\n')
            n1=float(input('Digite o número 1:'))
            n2=float(input('Digite o número 2:'))
            n3 = n1 + n2
            print(soma(n1, n2 ),'\n')
            print(verficador(n3))
        
        elif i==2:
            print(' O selecionado foi',i,'subtração\n')
            n1=float(input('Digite que não vai ser subtraído:'))
            n2=float(input('Digite que vai subtrair:'))
            n3 = n1 - n2
            print(sub(n1,n2),'\n')
            print(verficador(n3))
            
        elif i==3:
            print(' O selecionado foi',i,'multiplicação\n')
            n1=float(input('Digite o número 1:'))
            n2=float(input('Digite o número 2:'))
            n3 = n1 * n2
            print(mul(n1,n2),'\n')
            print(verficador(n3))
            
        elif i==4:
            print(' O selecionado foi',i,'divisão\n')
            n1 = float(input('Digite o númerador:'))
            n2 = float(input('Digite o denominador:'))
            while n2 == 0:
                n2=float(input('Não é possível divisão por 0, digite um novo valor:'))   
            n3 = n1/n2
            print(div(n1,n2),'\n')
            print(verficador(n3))   
            
        elif i==5:
            print('''\n\n    pprograma encerrado
                        😎😎😎😋        ''')
            break
        else:
            print('''\33[31m      
                    
                        -->Opção ínvalida não foi um valor de 1 à 5<--
                                                                        \33[31''')
            print()

# %% [markdown]
# <h3>Revisão Lógica: Laços</h3>
#
# 1 -  Escreva um programa que solicite ao usuário um número inteiro positivo
# e  realize  uma  contagem  regressiva  a  partir  desse  número  até  zero,
# imprimindo cada número no processo.
#
# 2  -  Escreva  um  programa  que  solicite  ao  usuário  um  número  inteiro  e
# imprima a tabuada desse número, de 1 a 10.
#
# 3  -  Escreva  um  programa  que  solicite  ao  usuário  uma  frase  e  conte
# quantas vogais (a, e, i, o, u) existem nessa frase.
#
# 4  -  Escreva  um  programa  que  possa  verificar  uma  sequência  de  10
# números  se são par ou ímpar.
#
# 5 - Hora de otimizar a questão número 3, após ter criado seu programa que
# conta  quantas  vogais  existem  numa  frase,  implemente  mais  uma
# funcionalidade.
# O programa agora deve imprimir a quantidade de vogais e  consoantes encontradas.

# %%
#1 -  Escreva um programa que solicite ao usuário um número inteiro positivo e  realize  uma  contagem  regressiva  a  partir  desse  número  até  zero, imprimindo cada número no processo.

numero = int(input('Digite um Número: '))
for c in range(numero,-1,-1): # precisa ser -1 para parar em zero 0
    print(c , end = ' ')

# %%
# 2  -  Escreva  um  programa  que  solicite  ao  usuário  um  número  inteiro  e  imprima a tabuada desse número, de 1 a 10 .

while True:
    
    numero = int(input('Digite o número da tabuada: '))
    
    if numero == 0:
        break
    else:
    # while numero == 0:
    #     print('🤷‍♂️🤷‍♂️🤷‍♂️ Número igual a !!!')
    #     numero = int(input('Digite o número diferente de 0 da tabuada: '))     
        for c in range(1,11):
            print(f'{abs(numero)} x {c} = {(abs(numero)*c)}')
    
    print('Digite 0 para encerrar a tabuada!!😎💖')

# %%
# 3  -  Escreva  um  programa  que  solicite  ao  usuário  uma  frase  e  conte  quantas vogais (a, e, i, o, u) existem nessa frase.

a = []
e = []
i = []
o = []
u = []
consoante = []

frase = input('Digite uma palavra: ')
frase = frase.upper()



for p in frase:
        if p == 'A':
            a.append(1)
        elif p == 'E':
            e.append(1)
        elif p == 'I':
            i.append(1)
        elif p == 'O':
            o.append(1)
        elif p == 'U':
            u.append(1)
        else:
            consoante.append(1)

        dicionario={'A':sum(a),'E':sum(e),'I':sum(i),'O':sum(o),'U':sum(u) ,'Consoante':sum(consoante) }
print(dicionario)
# Out:
# {'A': 3, 'E': 0, 'I': 1, 'O': 3, 'U': 0, 'Consoante': 3}

# %%
# 4  -  Escreva  um  programa  que  possa  verificar  uma  sequência  de  10  números  se são par ou ímpar.

for c in range (1,11):
    if c%2==0:
        print(f'{c} é par')
    else:
        print(f'{c} é ímpar')

# %%
# 3  -  Escreva  um  programa  que  solicite  ao  usuário  uma  frase  e  conte quantas vogais (a, e, i, o, u) existem nessa frase.
# 5 - Hora de otimizar a questão número 3, após ter criado seu programa que conta  quantas  vogais  existem  numa  frase,  implemente  mais  uma funcionalidade.
# O programa agora deve imprimir a quantidade de vogais e  consoantes encontradas.

a = []
e = []
i = []
o = []
u = []
consoante = []

frase = input('Digite uma palavra: ')
frase = frase.upper()



for p in frase:
        if p == 'A':
            a.append(1)
        elif p == 'E':
            e.append(1)
        elif p == 'I':
            i.append(1)
        elif p == 'O':
            o.append(1)
        elif p == 'U':
            u.append(1)
        else:
            consoante.append(1)

        dicionario={'A':sum(a),'E':sum(e),'I':sum(i),'O':sum(o),'U':sum(u) ,'Consoante':sum(consoante) }
print(dicionario)

# %% [markdown]
# <h3>Questões finais</h3>
#
# 1 - Você é um operador de caixa em um supermercado e precisa
# implementar um programa para registrar as compras dos clientes.
#
# O programa deve solicitar o nome e o preço de cada produto e somar o total da compra no final. O operador pode inserir o nome e o preço de cada produto repetidamente até que ele deseje encerrar a compra, digitando um valor especial (por exemplo, -1).
# Utilize o laço de repetição while para
# permitir a inserção contínua dos preços dos produtos até que o operador
# decida encerrar a compra.
#
# 2 - Você foi contratado como desenvolvedor para criar um programa que
# verifique a senha digitada pelos usuários. O programa deve solicitar ao
# usuário que digite uma senha e verificar se ela atende aos critérios
# estabelecidos. Os critérios são os seguintes:
# ● A senha deve ter no mínimo 8 caracteres e no máximo 12 caracteres.

# %%
# 1 - Você é um operador de caixa em um supermercado e precisa implementar um programa para registrar as compras dos clientes.

# O programa deve solicitar o nome e o preço de cada produto e somar o total da compra no final. O operador pode inserir o nome e o preço de cada 
#produto repetidamente até que ele deseje encerrar a compra, digitando um valor especial (por exemplo, -1). 
# Utilize o laço de repetição while para
# permitir a inserção contínua dos preços dos produtos até que o operador
# decida encerrar a compra.

c = 1
lista = []
valor_total = 0
while True:
    produto_nome = input(f'Digite o nome do Produto {c}:')
    porduto_valor = float(input(f'Digite o valor do Produto {produto_nome}:'))
    c += 1
    dicionario = {'Prodto':produto_nome,'Valor':porduto_valor}
    lista.append(dicionario)
    print('-'*100)
    print(lista)
        
    for y in lista:
        valor_total+= y['Valor']
    print(f'Até Agora você Gastou R$: {valor_total}')
    valor_total = 0
    print('-'*100)

    parar = input('Digite S para parar as Compras: ')

    if parar == 'S':
        valor_total = 0
        for y in lista:
            valor_total+= y['Valor']
        print('Sistema Finalizado !!!!')
        print(f'Comprou um total de {c - 1} produtos')
        print(f'Você gastou no total 😲R$: {valor_total}')
        break

# %%
# 2 - Você foi contratado como desenvolvedor para criar um programa que verifique a senha digitada pelos usuários. O programa deve solicitar ao usuário que digite uma 
#senha e verificar se ela atende aos critérios estabelecidos. Os critérios são os seguintes:
# ● A senha deve ter no mínimo 8 caracteres e no máximo 12 caracteres.


maisculo = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
minusculo = 'abcdefghijklmnopqrstuvwxyz'
numeros = '0123456789'

while True:
    controle_caract = False
    controle_maiuscula = False
    controle_minuscula = False
    controle_numeros = False

    senha = input('Digite a senha: ')
    n_caract =len(senha)
    
    if n_caract <= 12 and n_caract>=8:
        controle_caract = True

    for c in senha:
        if c in maisculo:
            controle_maiuscula = True
        if c in minusculo:
            controle_minuscula = True
        if c in numeros:
            controle_numeros = True
    
    if controle_caract is True and controle_maiuscula is True and controle_minuscula is True and controle_numeros is True:
        print(f'Sua senha {senha} foi aprovada')
        break
    else:
        print(f'Sua senha {senha} não foi aprovada')
